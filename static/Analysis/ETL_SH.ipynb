# %% [markdown]
# ## Impact of Seasonal Natural Gas Consumption on Air Quality
# - Analyze how seasonal variations in natural gas consumption influence air quality, focusing on the comparison between winter and summer months.

# %%
# Importing dependencies
#Python SQL Toolkit and ORM
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, text

#Pandas and Bokeh libraries
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.io import output_file

# %% [markdown]
# #### Fetching data from our database and converting it to pandas DataFrame

# %%
#Create Database Connection
engine = create_engine("sqlite:///../Resources/new_aqi_ngsDB.sqlite", echo=False)

# %%
#Refelect Database into ORM Classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['combined_df']

# %%
#map the combined_df class

combined_table_aqi_ng = Base.classes.combined_df

#create session
session = Session(engine)

# %%
#get a list of column names and types
inspector = inspect(engine)
columns = inspector.get_columns('combined_df')

for column in columns:
    print(column['name'], column['type'])
# Out:
# id INTEGER
# state_name TEXT
# state_id TEXT
# month INTEGER
# AQI INTEGER
# lat REAL
# lng REAL
# density INTEGER
# population INTEGER
# Category TEXT
# Commercial Consumption REAL
# Delivered to Consumers REAL
# Electric Power Consumption REAL
# Industrial Consumption REAL
# Residential Consumption REAL
# Vehicle Fuel Consumption REAL
# total REAL

# %%
#Query the data from our table
data_query = session.query(combined_table_aqi_ng.id,combined_table_aqi_ng.state_id,combined_table_aqi_ng.month,combined_table_aqi_ng.AQI,
                           combined_table_aqi_ng.lat,combined_table_aqi_ng.lng,combined_table_aqi_ng.Category,combined_table_aqi_ng.total ).all()

for item in data_query:
    print(item)
# Out:
# (0, 'AL', 1, 37, 33.3173, -86.8356, 'Good', 133551.0)
# (1, 'AL', 2, 38, 33.2297, -86.8105, 'Good', 114933.0)
# (2, 'AL', 3, 43, 33.1279, -86.8814, 'Good', 103717.0)
# (3, 'AL', 4, 47, 33.1279, -86.8814, 'Good', 96171.0)
# (4, 'AL', 5, 44, 33.1231, -86.8856, 'Good', 101999.0)
# (5, 'AL', 6, 38, 33.1279, -86.8814, 'Good', 115579.0)
# (6, 'AL', 7, 39, 33.1369, -86.8778, 'Good', 119120.0)
# (7, 'AL', 8, 42, 33.1135, -86.8943, 'Good', 124022.0)
# (8, 'AL', 9, 37, 33.1279, -86.8814, 'Good', 109530.0)
# (9, 'AL', 10, 37, 33.146, -86.8742, 'Good', 109041.0)
# (10, 'AL', 11, 38, 33.2614, -86.8268, 'Good', 115678.0)
# (11, 'AL', 12, 34, 33.3429, -86.7456, 'Good', 119300.0)
# (12, 'AK', 1, 58, 61.4802, -143.6454, 'Moderate', 15243.0)
# (13, 'AK', 2, 42, 61.4802, -143.6454, 'Good', 15370.0)
# (14, 'AK', 3, 29, 61.4802, -143.6454, 'Good', 15715.0)
# (15, 'AK', 4, 31, 61.6964, -144.322, 'Good', 11956.0)
# (16, 'AK', 5, 24, 61.4802, -143.6454, 'Good', 9288.0)
# (17, 'AK', 6, 21, 61.4802, -143.6454, 'Good', 7352.0)
# (18, 'AK', 7, 29, 61.4802, -143.6454, 'Good', 7429.0)
# (19, 'AK', 8, 19, 61.5467, -143.8536, 'Good', 8279.0)
# (20, 'AK', 9, 18, 61.4802, -143.6454, 'Good', 8563.0)
# (21, 'AK', 10, 26, 61.4802, -143.6454, 'Good', 12262.0)
# (22, 'AK', 11, 39, 61.4802, -143.6454, 'Good', 27444.0)
# (23, 'AK', 12, 49, 61.4802, -143.6454, 'Good', 30702.0)
# (24, 'AZ', 1, 52, 33.2722, -111.7838, 'Moderate', 85899.0)
# (25, 'AZ', 2, 42, 33.3992, -111.848, 'Good', 57896.0)
# (26, 'AZ', 3, 58, 33.3996, -111.8482, 'Moderate', 68198.0)
# (27, 'AZ', 4, 65, 33.4034, -111.8502, 'Moderate', 70656.0)
# (28, 'AZ', 5, 57, 33.4034, -111.8502, 'Moderate', 76338.0)
# (29, 'AZ', 6, 58, 33.424, -111.8594, 'Moderate', 83816.0)
# (30, 'AZ', 7, 56, 33.41, -111.8531, 'Moderate', 100532.0)
# (31, 'AZ', 8, 49, 33.4034, -111.8502, 'Good', 92511.0)
# (32, 'AZ', 9, 60, 33.4034, -111.8502, 'Moderate', 79408.0)
# (33, 'AZ', 10, 58, 33.3996, -111.8482, 'Moderate', 65184.0)
# (34, 'AZ', 11, 46, 33.4167, -111.8428, 'Good', 56316.0)
# (35, 'AZ', 12, 44, 33.4034, -111.8502, 'Good', 68984.0)
# (36, 'AR', 1, 30, 35.1338, -93.3515, 'Good', 63376.0)
# (37, 'AR', 2, 36, 35.1737, -93.3661, 'Good', 62280.0)
# (38, 'AR', 3, 42, 35.1597, -93.3612, 'Good', 65606.0)
# (39, 'AR', 4, 41, 35.1439, -93.3554, 'Good', 56729.0)
# (40, 'AR', 5, 37, 35.123, -93.3476, 'Good', 43956.0)
# (41, 'AR', 6, 42, 35.1326, -93.3513, 'Good', 53784.0)
# (42, 'AR', 7, 45, 35.1433, -93.3548, 'Good', 53336.0)
# (43, 'AR', 8, 44, 35.1375, -93.3532, 'Good', 55280.0)
# (44, 'AR', 9, 44, 35.1326, -93.3513, 'Good', 50256.0)
# (45, 'AR', 10, 37, 35.123, -93.3476, 'Good', 53532.0)
# (46, 'AR', 11, 38, 35.312, -93.4017, 'Good', 66092.0)
# (47, 'AR', 12, 36, 35.1375, -93.3532, 'Good', 66512.0)
# (48, 'CA', 1, 52, 37.347, -120.8032, 'Moderate', 390174.0)
# (49, 'CA', 2, 46, 37.3497, -120.8042, 'Good', 328402.0)
# (50, 'CA', 3, 44, 37.3292, -120.7881, 'Good', 354437.0)
# (51, 'CA', 4, 50, 37.3491, -120.8046, 'Good', 296046.0)
# (52, 'CA', 5, 54, 37.3136, -120.7666, 'Moderate', 280411.0)
# (53, 'CA', 6, 58, 37.3087, -120.7481, 'Moderate', 309926.0)
# (54, 'CA', 7, 68, 37.3194, -120.757, 'Moderate', 363851.0)
# (55, 'CA', 8, 86, 37.2941, -120.7389, 'Moderate', 350288.0)
# (56, 'CA', 9, 72, 37.2802, -120.7273, 'Moderate', 322554.0)
# (57, 'CA', 10, 56, 37.2232, -120.6834, 'Moderate', 329879.0)
# (58, 'CA', 11, 54, 37.2829, -120.7299, 'Moderate', 329524.0)
# (59, 'CA', 12, 50, 37.3167, -120.7555, 'Good', 429463.0)
# (60, 'CO', 1, 40, 39.5061, -106.0894, 'Good', 103680.0)
# (61, 'CO', 2, 43, 39.5031, -106.0891, 'Good', 99272.0)
# (62, 'CO', 3, 46, 39.5104, -106.0945, 'Good', 80861.0)
# (63, 'CO', 4, 46, 39.509, -106.0928, 'Good', 62891.0)
# (64, 'CO', 5, 48, 39.5061, -106.0894, 'Good', 51906.0)
# (65, 'CO', 6, 60, 39.509, -106.0928, 'Moderate', 44491.0)
# (66, 'CO', 7, 81, 39.475, -106.0566, 'Moderate', 47835.0)
# (67, 'CO', 8, 72, 39.4274, -105.9995, 'Moderate', 46616.0)
# (68, 'CO', 9, 55, 39.446, -106.0175, 'Moderate', 42636.0)
# (69, 'CO', 10, 38, 39.4339, -106.003, 'Good', 51632.0)
# (70, 'CO', 11, 36, 39.4229, -105.9913, 'Good', 72370.0)
# (71, 'CO', 12, 37, 39.4266, -105.9825, 'Good', 94323.0)
# (72, 'CT', 1, 36, 41.5307, -72.804, 'Good', 66580.0)
# (73, 'CT', 2, 38, 41.5354, -72.8087, 'Good', 61046.0)
# (74, 'CT', 3, 42, 41.5307, -72.804, 'Good', 56443.0)
# (75, 'CT', 4, 44, 41.5307, -72.804, 'Good', 39964.0)
# (76, 'CT', 5, 45, 41.5307, -72.804, 'Good', 36616.0)
# (77, 'CT', 6, 57, 41.5307, -72.804, 'Moderate', 41866.0)
# (78, 'CT', 7, 54, 41.5307, -72.804, 'Moderate', 41160.0)
# (79, 'CT', 8, 54, 41.5287, -72.8019, 'Moderate', 44678.0)
# (80, 'CT', 9, 36, 41.5307, -72.804, 'Good', 38105.0)
# (81, 'CT', 10, 29, 41.5307, -72.804, 'Good', 37195.0)
# (82, 'CT', 11, 35, 41.5307, -72.804, 'Good', 56049.0)
# (83, 'CT', 12, 38, 41.5307, -72.804, 'Good', 59595.0)
# (84, 'DE', 1, 36, 39.161, -75.5202, 'Good', 16203.0)
# (85, 'DE', 2, 38, 39.161, -75.5202, 'Good', 16103.0)
# (86, 'DE', 3, 38, 39.161, -75.5202, 'Good', 11206.0)
# (87, 'DE', 4, 44, 39.161, -75.5202, 'Good', 10576.0)
# (88, 'DE', 5, 47, 39.161, -75.5202, 'Good', 10360.0)
# (89, 'DE', 6, 41, 39.161, -75.5202, 'Good', 13153.0)
# (90, 'DE', 7, 50, 39.161, -75.5202, 'Good', 13796.0)
# (91, 'DE', 8, 41, 39.161, -75.5202, 'Good', 14730.0)
# (92, 'DE', 9, 38, 39.161, -75.5202, 'Good', 9690.0)
# (93, 'DC', 1, 43, 38.9047, -77.0163, 'Good', 8710.0)
# (94, 'DC', 2, 51, 38.9047, -77.0163, 'Moderate', 8640.0)
# (95, 'DC', 3, 47, 38.9047, -77.0163, 'Good', 6110.0)
# (96, 'DC', 4, 50, 38.9047, -77.0163, 'Good', 4076.0)
# (97, 'DC', 5, 57, 38.9047, -77.0163, 'Moderate', 2538.0)
# (98, 'DC', 6, 51, 38.9047, -77.0163, 'Moderate', 1898.0)
# (99, 'DC', 7, 69, 38.9047, -77.0163, 'Moderate', 1744.0)
# (100, 'DC', 8, 60, 38.9047, -77.0163, 'Moderate', 1998.0)
# (101, 'DC', 9, 44, 38.9047, -77.0163, 'Good', 1910.0)
# (102, 'DC', 10, 38, 38.9047, -77.0163, 'Good', 2583.0)
# (103, 'DC', 11, 42, 38.9047, -77.0163, 'Good', 6467.0)
# (104, 'DC', 12, 47, 38.9047, -77.0163, 'Good', 6435.0)
# (105, 'FL', 1, 38, 28.6042, -82.4005, 'Good', 223595.0)
# (106, 'FL', 2, 36, 28.6049, -82.4052, 'Good', 210259.0)
# (107, 'FL', 3, 41, 28.6002, -82.3988, 'Good', 227881.0)
# (108, 'FL', 4, 47, 28.6026, -82.3991, 'Good', 232734.0)
# (109, 'FL', 5, 44, 28.6019, -82.3987, 'Good', 269828.0)
# (110, 'FL', 6, 33, 28.6043, -82.3999, 'Good', 275468.0)
# (111, 'FL', 7, 34, 28.5845, -82.4156, 'Good', 302355.0)
# (112, 'FL', 8, 36, 28.5912, -82.4223, 'Good', 315116.0)
# (113, 'FL', 9, 36, 28.6063, -82.4001, 'Good', 287333.0)
# (114, 'FL', 10, 36, 28.6038, -82.4019, 'Good', 275908.0)
# (115, 'FL', 11, 37, 28.6043, -82.4006, 'Good', 221250.0)
# (116, 'FL', 12, 37, 28.6026, -82.3991, 'Good', 231316.0)
# (117, 'GA', 1, 35, 32.8602, -83.5619, 'Good', 165754.0)
# (118, 'GA', 2, 33, 32.8686, -83.5674, 'Good', 132315.0)
# (119, 'GA', 3, 45, 32.9262, -83.6939, 'Good', 112509.0)
# (120, 'GA', 4, 47, 32.9242, -83.6802, 'Good', 112635.0)
# (121, 'GA', 5, 42, 32.9482, -83.7036, 'Good', 107040.0)
# (122, 'GA', 6, 35, 32.939, -83.6937, 'Good', 113653.0)
# (123, 'GA', 7, 38, 32.9368, -83.6983, 'Good', 119046.0)
# (124, 'GA', 8, 39, 32.9495, -83.6888, 'Good', 122798.0)
# (125, 'GA', 9, 38, 32.9434, -83.6975, 'Good', 105298.0)
# (126, 'GA', 10, 35, 32.9291, -83.6959, 'Good', 115111.0)
# (127, 'GA', 11, 41, 32.7464, -83.4266, 'Good', 144623.0)
# (128, 'GA', 12, 43, 32.7315, -83.425, 'Good', 142861.0)
# (129, 'HI', 1, 20, 20.8836, -156.9662, 'Good', 424.0)
# (130, 'HI', 2, 19, 20.8836, -156.9662, 'Good', 399.0)
# (131, 'HI', 3, 19, 20.8836, -156.9662, 'Good', 441.0)
# (132, 'HI', 4, 16, 20.8836, -156.9662, 'Good', 494.0)
# (133, 'HI', 5, 15, 20.8836, -156.9662, 'Good', 433.0)
# (134, 'HI', 6, 12, 20.8836, -156.9662, 'Good', 488.0)
# (135, 'HI', 7, 14, 20.8836, -156.9662, 'Good', 478.0)
# (136, 'HI', 8, 14, 20.8836, -156.9662, 'Good', 510.0)
# (137, 'HI', 9, 13, 20.8836, -156.9662, 'Good', 484.0)
# (138, 'HI', 10, 18, 20.8841, -156.989, 'Good', 460.0)
# (139, 'HI', 11, 17, 20.8836, -156.9662, 'Good', 463.0)
# (140, 'HI', 12, 16, 20.8705, -156.9403, 'Good', 490.0)
# (141, 'ID', 1, 28, 45.2352, -115.0954, 'Good', 30726.0)
# (142, 'ID', 2, 22, 45.1936, -115.0761, 'Good', 27704.0)
# (143, 'ID', 3, 26, 45.1936, -115.0761, 'Good', 24942.0)
# (144, 'ID', 4, 27, 45.2006, -115.0794, 'Good', 19084.0)
# (145, 'ID', 5, 24, 45.2179, -115.0851, 'Good', 15022.0)
# (146, 'ID', 6, 29, 45.2603, -115.0967, 'Good', 13976.0)
# (147, 'ID', 7, 60, 45.1936, -115.0761, 'Moderate', 17332.0)
# (148, 'ID', 8, 72, 45.1936, -115.0761, 'Moderate', 15350.0)
# (149, 'ID', 9, 42, 45.1936, -115.0761, 'Good', 15730.0)
# (150, 'ID', 10, 24, 45.1936, -115.0761, 'Good', 18374.0)
# (151, 'ID', 11, 28, 45.1031, -114.998, 'Good', 23824.0)
# (152, 'ID', 12, 22, 45.1628, -115.0551, 'Good', 30806.0)
# (153, 'IL', 1, 40, 40.417, -88.8775, 'Good', 299271.0)
# (154, 'IL', 2, 44, 40.3919, -88.8828, 'Good', 304644.0)
# (155, 'IL', 3, 42, 40.2434, -89.1046, 'Good', 208032.0)
# (156, 'IL', 4, 43, 40.2503, -89.0835, 'Good', 144950.0)
# (157, 'IL', 5, 43, 40.2434, -89.1046, 'Good', 114082.0)
# (158, 'IL', 6, 52, 40.2434, -89.1046, 'Moderate', 107864.0)
# (159, 'IL', 7, 51, 40.2434, -89.1046, 'Moderate', 114199.0)
# (160, 'IL', 8, 49, 40.2693, -89.1174, 'Good', 124743.0)
# (161, 'IL', 9, 45, 40.2434, -89.1046, 'Good', 97853.0)
# (162, 'IL', 10, 35, 40.2434, -89.1046, 'Good', 124706.0)
# (163, 'IL', 11, 38, 40.4368, -88.8829, 'Good', 199777.0)
# (164, 'IL', 12, 41, 40.4242, -88.888, 'Good', 241718.0)
# (165, 'IN', 1, 36, 40.1171, -86.3857, 'Good', 197280.0)
# (166, 'IN', 2, 45, 40.1162, -86.3863, 'Good', 192212.0)
# (167, 'IN', 3, 40, 40.1239, -86.3776, 'Good', 146516.0)
# (168, 'IN', 4, 44, 40.1193, -86.3797, 'Good', 120714.0)
# (169, 'IN', 5, 44, 40.1112, -86.3815, 'Good', 109294.0)
# (170, 'IN', 6, 50, 40.1263, -86.3849, 'Good', 106280.0)
# (171, 'IN', 7, 51, 40.1183, -86.3768, 'Moderate', 107561.0)
# (172, 'IN', 8, 46, 40.1239, -86.3776, 'Good', 111888.0)
# (173, 'IN', 9, 42, 40.1215, -86.3807, 'Good', 97096.0)
# (174, 'IN', 10, 34, 40.1165, -86.3791, 'Good', 114339.0)
# (175, 'IN', 11, 35, 40.1193, -86.3797, 'Good', 160970.0)
# (176, 'IN', 12, 35, 40.1173, -86.3835, 'Good', 167825.0)
# (177, 'IA', 1, 44, 41.876, -92.1919, 'Good', 89072.0)
# (178, 'IA', 2, 46, 41.9078, -92.2126, 'Good', 88522.0)
# (179, 'IA', 3, 42, 41.8854, -92.1976, 'Good', 67536.0)
# (180, 'IA', 4, 41, 41.8768, -92.194, 'Good', 57157.0)
# (181, 'IA', 5, 37, 41.8807, -92.195, 'Good', 47622.0)
# (182, 'IA', 6, 47, 41.876, -92.1915, 'Good', 52772.0)
# (183, 'IA', 7, 53, 41.8806, -92.1944, 'Moderate', 52073.0)
# (184, 'IA', 8, 46, 41.9047, -92.2105, 'Good', 52178.0)
# (185, 'IA', 9, 40, 41.8808, -92.1947, 'Good', 49330.0)
# (186, 'IA', 10, 32, 41.8312, -91.8581, 'Good', 54784.0)
# (187, 'IA', 11, 34, 41.8188, -91.8359, 'Good', 72577.0)
# (188, 'IA', 12, 40, 41.8299, -91.8158, 'Good', 82155.0)
# (189, 'KS', 1, 32, 38.1956, -97.4793, 'Good', 64328.0)
# (190, 'KS', 2, 30, 38.1851, -97.5415, 'Good', 69874.0)
# (191, 'KS', 3, 32, 38.183, -97.5543, 'Good', 47590.0)
# (192, 'KS', 4, 37, 38.1836, -97.5503, 'Good', 40910.0)
# (193, 'KS', 5, 28, 38.1914, -97.5039, 'Good', 29491.0)
# (194, 'KS', 6, 43, 38.1617, -97.686, 'Good', 31950.0)
# (195, 'KS', 7, 45, 38.1617, -97.686, 'Good', 35250.0)
# (196, 'KS', 8, 45, 38.1617, -97.686, 'Good', 37381.0)
# (197, 'KS', 9, 41, 38.1617, -97.686, 'Good', 30232.0)
# (198, 'KS', 10, 32, 38.1617, -97.686, 'Good', 33598.0)
# (199, 'KS', 11, 33, 38.1708, -97.633, 'Good', 45815.0)
# (200, 'KS', 12, 40, 38.1705, -97.6347, 'Good', 54086.0)
# (201, 'KY', 1, 36, 37.3185, -85.8382, 'Good', 76638.0)
# (202, 'KY', 2, 42, 37.3252, -85.8639, 'Good', 74972.0)
# (203, 'KY', 3, 42, 37.3202, -85.8384, 'Good', 56122.0)
# (204, 'KY', 4, 45, 37.3202, -85.8384, 'Good', 42805.0)
# (205, 'KY', 5, 44, 37.3235, -85.8482, 'Good', 41967.0)
# (206, 'KY', 6, 43, 37.3202, -85.8384, 'Good', 42903.0)
# (207, 'KY', 7, 54, 37.3202, -85.8384, 'Moderate', 43926.0)
# (208, 'KY', 8, 44, 37.3202, -85.8384, 'Good', 44715.0)
# (209, 'KY', 9, 39, 37.3202, -85.8384, 'Good', 38163.0)
# (210, 'KY', 10, 37, 37.3202, -85.8384, 'Good', 43189.0)
# (211, 'KY', 11, 37, 37.3168, -85.845, 'Good', 63000.0)
# (212, 'KY', 12, 37, 37.3169, -85.8448, 'Good', 60094.0)
# (213, 'LA', 1, 35, 30.7928, -91.8, 'Good', 264631.0)
# (214, 'LA', 2, 37, 30.6824, -91.7979, 'Good', 234438.0)
# (215, 'LA', 3, 40, 30.7944, -91.8142, 'Good', 235093.0)
# (216, 'LA', 4, 43, 30.7837, -91.8259, 'Good', 230523.0)
# (217, 'LA', 5, 41, 30.7953, -91.8113, 'Good', 231883.0)
# (218, 'LA', 6, 38, 30.7947, -91.8134, 'Good', 246815.0)
# (219, 'LA', 7, 44, 30.7932, -91.8085, 'Good', 271358.0)
# (220, 'LA', 8, 46, 30.81, -91.8285, 'Good', 252154.0)
# (221, 'LA', 9, 43, 30.8676, -91.9162, 'Good', 201108.0)
# (222, 'LA', 10, 42, 30.7953, -91.8113, 'Good', 246114.0)
# (223, 'LA', 11, 43, 30.7898, -91.7901, 'Good', 256880.0)
# (224, 'LA', 12, 35, 30.7932, -91.8085, 'Good', 259489.0)
# (225, 'ME', 1, 27, 44.2147, -69.7151, 'Good', 10776.0)
# (226, 'ME', 2, 31, 44.2092, -69.7379, 'Good', 11436.0)
# (227, 'ME', 3, 40, 44.2142, -69.6293, 'Good', 8686.0)
# (228, 'ME', 4, 40, 44.2137, -69.6263, 'Good', 6850.0)
# (229, 'ME', 5, 38, 44.2125, -69.6198, 'Good', 6691.0)
# (230, 'ME', 6, 44, 44.2125, -69.6198, 'Good', 7288.0)
# (231, 'ME', 7, 32, 44.2125, -69.6198, 'Good', 7984.0)
# (232, 'ME', 8, 36, 44.2131, -69.6229, 'Good', 10117.0)
# (233, 'ME', 9, 29, 44.2125, -69.6198, 'Good', 8040.0)
# (234, 'ME', 10, 20, 44.2109, -69.7251, 'Good', 8774.0)
# (235, 'ME', 11, 25, 44.2074, -69.7428, 'Good', 9712.0)
# (236, 'ME', 12, 26, 44.1825, -69.775, 'Good', 9930.0)
# (237, 'MD', 1, 37, 38.9681, -76.5003, 'Good', 65266.0)
# (238, 'MD', 2, 41, 38.9681, -76.5003, 'Good', 62878.0)
# (239, 'MD', 3, 43, 38.9681, -76.5003, 'Good', 50740.0)
# (240, 'MD', 4, 46, 38.9681, -76.5003, 'Good', 44121.0)
# (241, 'MD', 5, 50, 38.9681, -76.5003, 'Good', 31249.0)
# (242, 'MD', 6, 45, 38.9681, -76.5003, 'Good', 26191.0)
# (243, 'MD', 7, 54, 38.9681, -76.5003, 'Moderate', 32743.0)
# (244, 'MD', 8, 48, 38.9681, -76.5003, 'Good', 33530.0)
# (245, 'MD', 9, 40, 38.9681, -76.5003, 'Good', 30221.0)
# (246, 'MD', 10, 36, 39.1656, -76.8049, 'Good', 35132.0)
# (247, 'MD', 11, 38, 39.1656, -76.8049, 'Good', 56571.0)
# (248, 'MD', 12, 37, 39.1442, -76.7637, 'Good', 52806.0)
# (249, 'MA', 1, 39, 42.1227, -71.86, 'Good', 114415.0)
# (250, 'MA', 2, 42, 42.1324, -71.8782, 'Good', 109025.0)
# (251, 'MA', 3, 42, 42.1359, -71.8848, 'Good', 83030.0)
# (252, 'MA', 4, 42, 42.1272, -71.8684, 'Good', 55025.0)
# (253, 'MA', 5, 44, 42.1314, -71.8764, 'Good', 37580.0)
# (254, 'MA', 6, 48, 42.1227, -71.86, 'Good', 45361.0)
# (255, 'MA', 7, 44, 42.1227, -71.86, 'Good', 45033.0)
# (256, 'MA', 8, 43, 42.1227, -71.86, 'Good', 46886.0)
# (257, 'MA', 9, 35, 42.1272, -71.8684, 'Good', 36703.0)
# (258, 'MA', 10, 33, 42.1314, -71.8764, 'Good', 44283.0)
# (259, 'MA', 11, 37, 42.1227, -71.86, 'Good', 64481.0)
# (260, 'MA', 12, 38, 42.1227, -71.86, 'Good', 88576.0)
# (261, 'MI', 1, 39, 42.9453, -84.6941, 'Good', 237017.0)
# (262, 'MI', 2, 41, 42.9861, -84.832, 'Good', 250744.0)
# (263, 'MI', 3, 39, 43.0736, -85.0842, 'Good', 163404.0)
# (264, 'MI', 4, 40, 43.0762, -85.0861, 'Good', 130611.0)
# (265, 'MI', 5, 43, 43.0826, -85.0919, 'Good', 101429.0)
# (266, 'MI', 6, 51, 42.9812, -85.0042, 'Moderate', 92445.0)
# (267, 'MI', 7, 46, 43.0049, -84.9856, 'Good', 92604.0)
# (268, 'MI', 8, 48, 42.9941, -85.0159, 'Good', 97326.0)
# (269, 'MI', 9, 37, 42.988, -85.0068, 'Good', 82786.0)
# (270, 'MI', 10, 32, 42.9703, -84.9879, 'Good', 108286.0)
# (271, 'MI', 11, 35, 42.8362, -84.5793, 'Good', 179093.0)
# (272, 'MI', 12, 39, 42.8514, -84.5881, 'Good', 200536.0)
# (273, 'MN', 1, 36, 45.5763, -93.7413, 'Good', 122666.0)
# (274, 'MN', 2, 41, 45.5605, -93.7238, 'Good', 120374.0)
# (275, 'MN', 3, 37, 45.4837, -93.6367, 'Good', 95859.0)
# (276, 'MN', 4, 34, 45.5046, -93.6647, 'Good', 73678.0)
# (277, 'MN', 5, 38, 45.4572, -93.6051, 'Good', 57212.0)
# (278, 'MN', 6, 51, 45.4607, -93.6553, 'Moderate', 55166.0)
# (279, 'MN', 7, 67, 45.4875, -93.6715, 'Moderate', 53069.0)
# (280, 'MN', 8, 49, 45.5196, -93.691, 'Good', 50613.0)
# (281, 'MN', 9, 35, 45.5196, -93.691, 'Good', 45582.0)
# (282, 'MN', 10, 31, 45.4795, -93.6871, 'Good', 63962.0)
# (283, 'MN', 11, 27, 45.6536, -93.8464, 'Good', 95595.0)
# (284, 'MN', 12, 29, 45.7167, -93.8209, 'Good', 126513.0)
# (285, 'MS', 1, 37, 31.9486, -89.8321, 'Good', 109245.0)
# (286, 'MS', 2, 39, 31.8992, -89.8074, 'Good', 96231.0)
# (287, 'MS', 3, 41, 32.408, -89.4583, 'Good', 70918.0)
# (288, 'MS', 4, 42, 32.408, -89.4583, 'Good', 83081.0)
# (289, 'MS', 5, 40, 32.3935, -89.4445, 'Good', 84257.0)
# (290, 'MS', 6, 35, 32.408, -89.4583, 'Good', 92720.0)
# (291, 'MS', 7, 36, 32.3878, -89.4662, 'Good', 97489.0)
# (292, 'MS', 8, 39, 32.4527, -89.4731, 'Good', 96508.0)
# (293, 'MS', 9, 38, 32.408, -89.4583, 'Good', 79858.0)
# (294, 'MS', 10, 38, 32.42, -89.4598, 'Good', 76700.0)
# (295, 'MS', 11, 43, 31.9486, -89.8321, 'Good', 80716.0)
# (296, 'MS', 12, 39, 31.9486, -89.8321, 'Good', 84558.0)
# (297, 'MO', 1, 36, 38.2448, -93.4682, 'Good', 88554.0)
# (298, 'MO', 2, 32, 38.2957, -93.4336, 'Good', 95064.0)
# (299, 'MO', 3, 43, 38.423, -93.1345, 'Good', 47888.0)
# (300, 'MO', 4, 43, 38.3893, -93.1369, 'Good', 37883.0)
# (301, 'MO', 5, 38, 38.3842, -93.1373, 'Good', 28584.0)
# (302, 'MO', 6, 51, 38.472, -93.1309, 'Moderate', 32040.0)
# (303, 'MO', 7, 51, 38.472, -93.1309, 'Moderate', 32018.0)
# (304, 'MO', 8, 46, 38.472, -93.1309, 'Good', 32653.0)
# (305, 'MO', 9, 46, 38.472, -93.1309, 'Good', 26056.0)
# (306, 'MO', 10, 36, 38.472, -93.1309, 'Good', 31792.0)
# (307, 'MO', 11, 34, 38.3579, -93.4827, 'Good', 54175.0)
# (308, 'MO', 12, 40, 38.3579, -93.4827, 'Good', 59615.0)
# (309, 'MT', 1, 34, 46.6519, -111.9906, 'Good', 19446.0)
# (310, 'MT', 2, 34, 46.6519, -111.9906, 'Good', 20459.0)
# (311, 'MT', 3, 34, 46.6559, -112.0065, 'Good', 15050.0)
# (312, 'MT', 4, 32, 46.6687, -112.0573, 'Good', 12744.0)
# (313, 'MT', 5, 27, 46.7253, -112.2828, 'Good', 10126.0)
# (314, 'MT', 6, 33, 46.6561, -112.007, 'Good', 7165.0)
# (315, 'MT', 7, 80, 46.6519, -111.9906, 'Moderate', 7064.0)
# (316, 'MT', 8, 65, 46.6519, -111.9906, 'Moderate', 8332.0)
# (317, 'MT', 9, 53, 46.6519, -111.9906, 'Moderate', 8693.0)
# (318, 'MT', 10, 32, 46.6519, -111.9906, 'Good', 11479.0)
# (319, 'MT', 11, 33, 46.6602, -112.0236, 'Good', 14605.0)
# (320, 'MT', 12, 32, 46.6519, -111.9906, 'Good', 17460.0)
# (321, 'NE', 1, 29, 41.2937, -99.0743, 'Good', 43907.0)
# (322, 'NE', 2, 32, 41.3093, -99.1516, 'Good', 48125.0)
# (323, 'NE', 3, 30, 41.2157, -98.6879, 'Good', 31833.0)
# (324, 'NE', 4, 31, 41.1932, -98.5164, 'Good', 23977.0)
# (325, 'NE', 5, 26, 41.2255, -98.6989, 'Good', 19892.0)
# (326, 'NE', 6, 40, 41.0928, -98.4345, 'Good', 23991.0)
# (327, 'NE', 7, 47, 41.009, -97.9661, 'Good', 25261.0)
# (328, 'NE', 8, 46, 40.9598, -97.8745, 'Good', 24068.0)
# (329, 'NE', 9, 38, 41.0273, -98.2994, 'Good', 19929.0)
# (330, 'NE', 10, 30, 41.0103, -98.1976, 'Good', 23515.0)
# (331, 'NE', 11, 23, 41.1131, -98.6076, 'Good', 30785.0)
# (332, 'NE', 12, 25, 41.0613, -98.5534, 'Good', 37222.0)
# (333, 'NV', 1, 32, 38.721, -118.0163, 'Good', 59493.0)
# (334, 'NV', 2, 30, 38.6515, -117.918, 'Good', 50319.0)
# (335, 'NV', 3, 32, 38.6451, -117.9105, 'Good', 51209.0)
# (336, 'NV', 4, 38, 38.6622, -117.933, 'Good', 41665.0)
# (337, 'NV', 5, 39, 38.6689, -117.9424, 'Good', 39105.0)
# (338, 'NV', 6, 43, 38.741, -118.043, 'Good', 50948.0)
# (339, 'NV', 7, 64, 38.7376, -118.0384, 'Moderate', 56476.0)
# (340, 'NV', 8, 92, 38.741, -118.043, 'Moderate', 53470.0)
# (341, 'NV', 9, 56, 38.7375, -118.0382, 'Moderate', 46280.0)
# (342, 'NV', 10, 33, 38.738, -118.04, 'Good', 39067.0)
# (343, 'NV', 11, 32, 38.741, -118.043, 'Good', 40541.0)
# (344, 'NV', 12, 32, 38.741, -118.043, 'Good', 51993.0)
# (345, 'NH', 1, 34, 43.4745, -71.7637, 'Good', 12428.0)
# (346, 'NH', 2, 36, 43.4783, -71.7599, 'Good', 12285.0)
# (347, 'NH', 3, 41, 43.4338, -71.7297, 'Good', 7876.0)
# (348, 'NH', 4, 40, 43.4338, -71.7297, 'Good', 7364.0)
# (349, 'NH', 5, 41, 43.4338, -71.7297, 'Good', 7252.0)
# (350, 'NH', 6, 42, 43.4338, -71.7297, 'Good', 9242.0)
# (351, 'NH', 7, 35, 43.4338, -71.7297, 'Good', 10265.0)
# (352, 'NH', 8, 37, 43.4338, -71.7297, 'Good', 11062.0)
# (353, 'NH', 9, 30, 43.4338, -71.7297, 'Good', 9991.0)
# (354, 'NH', 10, 27, 43.4745, -71.7637, 'Good', 11212.0)
# (355, 'NH', 11, 28, 43.425, -71.7884, 'Good', 7112.0)
# (356, 'NH', 12, 31, 43.4745, -71.7637, 'Good', 9860.0)
# (357, 'NJ', 1, 34, 39.6896, -74.7383, 'Good', 182631.0)
# (358, 'NJ', 2, 37, 39.6933, -74.7417, 'Good', 173609.0)
# (359, 'NJ', 3, 39, 39.6896, -74.7383, 'Good', 128116.0)
# (360, 'NJ', 4, 43, 39.6896, -74.7383, 'Good', 93339.0)
# (361, 'NJ', 5, 46, 39.692, -74.7355, 'Good', 75510.0)
# (362, 'NJ', 6, 43, 39.693, -74.7415, 'Good', 82910.0)
# (363, 'NJ', 7, 49, 39.6896, -74.7383, 'Good', 87752.0)
# (364, 'NJ', 8, 45, 39.6896, -74.7383, 'Good', 88496.0)
# (365, 'NJ', 9, 37, 39.6896, -74.7383, 'Good', 71218.0)
# (366, 'NJ', 10, 35, 39.6929, -74.7414, 'Good', 85074.0)
# (367, 'NJ', 11, 34, 39.6896, -74.7383, 'Good', 116747.0)
# (368, 'NJ', 12, 36, 39.6896, -74.7383, 'Good', 142787.0)
# (369, 'NM', 1, 35, 34.2073, -105.9774, 'Good', 39300.0)
# (370, 'NM', 2, 34, 34.2043, -105.9817, 'Good', 33890.0)
# (371, 'NM', 3, 43, 34.1086, -106.0052, 'Good', 31734.0)
# (372, 'NM', 4, 42, 34.2074, -105.981, 'Good', 22092.0)
# (373, 'NM', 5, 47, 34.1922, -105.974, 'Good', 24054.0)
# (374, 'NM', 6, 61, 34.1666, -106.0493, 'Moderate', 24922.0)
# (375, 'NM', 7, 62, 34.1616, -106.0493, 'Moderate', 25735.0)
# (376, 'NM', 8, 54, 34.012, -106.0819, 'Moderate', 25037.0)
# (377, 'NM', 9, 49, 34.1185, -106.0594, 'Good', 21854.0)
# (378, 'NM', 10, 41, 34.2036, -106.0414, 'Good', 20167.0)
# (379, 'NM', 11, 41, 34.2098, -106.0235, 'Good', 25468.0)
# (380, 'NM', 12, 39, 34.1586, -106.0509, 'Good', 29677.0)
# (381, 'NY', 1, 36, 42.6155, -76.4359, 'Good', 340670.0)
# (382, 'NY', 2, 40, 42.6098, -76.433, 'Good', 325202.0)
# (383, 'NY', 3, 40, 42.6176, -76.4317, 'Good', 261556.0)
# (384, 'NY', 4, 39, 42.6174, -76.4319, 'Good', 179349.0)
# (385, 'NY', 5, 44, 42.6113, -76.4476, 'Good', 154500.0)
# (386, 'NY', 6, 46, 42.623, -76.4264, 'Good', 162593.0)
# (387, 'NY', 7, 44, 42.6192, -76.4278, 'Good', 168397.0)
# (388, 'NY', 8, 42, 42.6173, -76.4419, 'Good', 177128.0)
# (389, 'NY', 9, 31, 42.6001, -76.4351, 'Good', 136299.0)
# (390, 'NY', 10, 29, 42.617, -76.4319, 'Good', 148274.0)
# (391, 'NY', 11, 32, 42.6214, -76.4304, 'Good', 226613.0)
# (392, 'NY', 12, 36, 42.6148, -76.4037, 'Good', 282560.0)
# (393, 'NC', 1, 25, 35.5116, -79.0644, 'Good', 137457.0)
# (394, 'NC', 2, 24, 35.5237, -79.0648, 'Good', 114700.0)
# (395, 'NC', 3, 41, 35.5825, -79.0389, 'Good', 94568.0)
# (396, 'NC', 4, 49, 35.5721, -78.9915, 'Good', 70407.0)
# (397, 'NC', 5, 47, 35.5777, -79.0197, 'Good', 73302.0)
# (398, 'NC', 6, 36, 35.573, -78.9933, 'Good', 82670.0)
# (399, 'NC', 7, 44, 35.5682, -79.0053, 'Good', 108787.0)
# (400, 'NC', 8, 41, 35.5668, -79.013, 'Good', 107264.0)
# (401, 'NC', 9, 39, 35.5677, -79.0251, 'Good', 88809.0)
# (402, 'NC', 10, 35, 35.5691, -79.0026, 'Good', 93518.0)
# (403, 'NC', 11, 30, 35.5277, -79.0135, 'Good', 131338.0)
# (404, 'NC', 12, 34, 35.5384, -79.0425, 'Good', 124006.0)
# (405, 'ND', 1, 37, 47.2022, -100.4173, 'Good', 19202.0)
# (406, 'ND', 2, 33, 47.2022, -100.4173, 'Good', 17354.0)
# (407, 'ND', 3, 35, 47.2047, -100.398, 'Good', 16242.0)
# (408, 'ND', 4, 39, 47.2022, -100.4173, 'Good', 13438.0)
# (409, 'ND', 5, 41, 47.2022, -100.4173, 'Good', 11532.0)
# (410, 'ND', 6, 48, 47.2079, -100.4781, 'Good', 10792.0)
# (411, 'ND', 7, 77, 47.2022, -100.4173, 'Moderate', 10288.0)
# (412, 'ND', 8, 65, 47.2022, -100.4173, 'Moderate', 9900.0)
# (413, 'ND', 9, 39, 47.1572, -100.3799, 'Good', 8652.0)
# (414, 'ND', 10, 38, 47.2022, -100.4173, 'Good', 10683.0)
# (415, 'ND', 11, 26, 47.2022, -100.4173, 'Good', 13373.0)
# (416, 'ND', 12, 32, 47.2022, -100.4173, 'Good', 16563.0)
# (417, 'OH', 1, 38, 40.3131, -82.8594, 'Good', 293025.0)
# (418, 'OH', 2, 44, 40.3066, -82.8631, 'Good', 289097.0)
# (419, 'OH', 3, 41, 40.3067, -82.6764, 'Good', 224654.0)
# (420, 'OH', 4, 43, 40.3029, -82.6793, 'Good', 171176.0)
# (421, 'OH', 5, 46, 40.3061, -82.6738, 'Good', 151216.0)
# (422, 'OH', 6, 46, 40.3081, -82.6766, 'Good', 127138.0)
# (423, 'OH', 7, 49, 40.315, -82.6701, 'Good', 131086.0)
# (424, 'OH', 8, 46, 40.3154, -82.6727, 'Good', 140200.0)
# (425, 'OH', 9, 40, 40.3101, -82.6778, 'Good', 121537.0)
# (426, 'OH', 10, 33, 40.3058, -82.6717, 'Good', 155738.0)
# (427, 'OH', 11, 34, 40.3166, -82.851, 'Good', 231775.0)
# (428, 'OH', 12, 35, 40.3086, -82.8609, 'Good', 247342.0)
# (429, 'OK', 1, 42, 35.7105, -96.5573, 'Good', 131333.0)
# (430, 'OK', 2, 46, 35.7557, -96.545, 'Good', 119150.0)
# (431, 'OK', 3, 51, 35.702, -96.5737, 'Moderate', 91048.0)
# (432, 'OK', 4, 53, 35.706, -96.5756, 'Moderate', 79749.0)
# (433, 'OK', 5, 40, 35.7102, -96.5777, 'Good', 80357.0)
# (434, 'OK', 6, 51, 35.7102, -96.5777, 'Moderate', 92008.0)
# (435, 'OK', 7, 58, 35.7102, -96.5777, 'Moderate', 109190.0)
# (436, 'OK', 8, 55, 35.7102, -96.5777, 'Moderate', 108627.0)
# (437, 'OK', 9, 57, 35.7102, -96.5777, 'Moderate', 90823.0)
# (438, 'OK', 10, 42, 35.7102, -96.5777, 'Good', 85016.0)
# (439, 'OK', 11, 37, 35.7016, -96.583, 'Good', 85050.0)
# (440, 'OK', 12, 41, 35.699, -96.6284, 'Good', 90655.0)
# (441, 'OR', 1, 36, 44.2174, -121.9431, 'Good', 57352.0)
# (442, 'OR', 2, 29, 44.2138, -121.9375, 'Good', 55610.0)
# (443, 'OR', 3, 30, 44.2174, -121.9431, 'Good', 56003.0)
# (444, 'OR', 4, 24, 44.2174, -121.9431, 'Good', 43228.0)
# (445, 'OR', 5, 24, 44.2174, -121.9431, 'Good', 29407.0)
# (446, 'OR', 6, 25, 44.2174, -121.9431, 'Good', 33345.0)
# (447, 'OR', 7, 36, 44.2174, -121.9431, 'Good', 41366.0)
# (448, 'OR', 8, 67, 44.2174, -121.9431, 'Moderate', 42916.0)
# (449, 'OR', 9, 51, 44.2174, -121.9431, 'Moderate', 42813.0)
# (450, 'OR', 10, 25, 44.2019, -121.9972, 'Good', 46633.0)
# (451, 'OR', 11, 36, 44.166, -121.9713, 'Good', 51110.0)
# (452, 'OR', 12, 29, 44.1107, -122.0016, 'Good', 63934.0)
# (453, 'PA', 1, 38, 40.5988, -77.4053, 'Good', 335388.0)
# (454, 'PA', 2, 42, 40.6642, -77.5486, 'Good', 311497.0)
# (455, 'PA', 3, 42, 40.6256, -77.4828, 'Good', 262276.0)
# (456, 'PA', 4, 43, 40.6649, -77.5302, 'Good', 203576.0)
# (457, 'PA', 5, 44, 40.663, -77.4967, 'Good', 201616.0)
# (458, 'PA', 6, 44, 40.6634, -77.5416, 'Good', 207257.0)
# (459, 'PA', 7, 50, 40.6653, -77.5173, 'Good', 218902.0)
# (460, 'PA', 8, 44, 40.6615, -77.5513, 'Good', 221557.0)
# (461, 'PA', 9, 37, 40.6551, -77.6114, 'Good', 203501.0)
# (462, 'PA', 10, 35, 40.6581, -77.54, 'Good', 201468.0)
# (463, 'PA', 11, 39, 40.6475, -77.4283, 'Good', 269032.0)
# (464, 'PA', 12, 44, 40.647, -77.4382, 'Good', 315395.0)
# (465, 'RI', 1, 38, 41.823, -71.4187, 'Good', 19877.0)
# (466, 'RI', 2, 43, 41.823, -71.4187, 'Good', 16588.0)
# (467, 'RI', 3, 44, 41.823, -71.4187, 'Good', 16855.0)
# (468, 'RI', 4, 45, 41.823, -71.4187, 'Good', 13455.0)
# (469, 'RI', 5, 46, 41.823, -71.4187, 'Good', 12290.0)
# (470, 'RI', 6, 56, 41.823, -71.4187, 'Moderate', 15363.0)
# (471, 'RI', 7, 52, 41.823, -71.4187, 'Moderate', 16166.0)
# (472, 'RI', 8, 56, 41.823, -71.4187, 'Moderate', 17215.0)
# (473, 'RI', 9, 40, 41.823, -71.4187, 'Good', 15545.0)
# (474, 'RI', 10, 36, 41.823, -71.4187, 'Good', 18911.0)
# (475, 'RI', 11, 37, 41.823, -71.4187, 'Good', 18828.0)
# (476, 'RI', 12, 41, 41.823, -71.4187, 'Good', 19490.0)
# (477, 'SC', 1, 33, 34.1129, -80.9567, 'Good', 66962.0)
# (478, 'SC', 2, 35, 34.1319, -80.8571, 'Good', 56430.0)
# (479, 'SC', 3, 43, 34.0869, -80.6394, 'Good', 48452.0)
# (480, 'SC', 4, 51, 34.0869, -80.6394, 'Moderate', 51890.0)
# (481, 'SC', 5, 48, 34.0869, -80.6394, 'Good', 49454.0)
# (482, 'SC', 6, 36, 34.0869, -80.6394, 'Good', 50790.0)
# (483, 'SC', 7, 43, 34.0869, -80.6394, 'Good', 54381.0)
# (484, 'SC', 8, 40, 34.0869, -80.6394, 'Good', 58090.0)
# (485, 'SC', 9, 42, 34.0869, -80.6394, 'Good', 53167.0)
# (486, 'SC', 10, 37, 34.0869, -80.6394, 'Good', 55261.0)
# (487, 'SC', 11, 37, 34.1365, -80.878, 'Good', 62463.0)
# (488, 'SC', 12, 41, 34.1504, -81.0612, 'Good', 66419.0)
# (489, 'SD', 1, 34, 44.4438, -98.7799, 'Good', 17487.0)
# (490, 'SD', 2, 32, 44.4208, -98.7192, 'Good', 19426.0)
# (491, 'SD', 3, 33, 44.5288, -98.9728, 'Good', 15190.0)
# (492, 'SD', 4, 32, 44.4438, -98.7799, 'Good', 14174.0)
# (493, 'SD', 5, 33, 44.4445, -98.7632, 'Good', 11686.0)
# (494, 'SD', 6, 46, 44.4438, -98.7799, 'Good', 12052.0)
# (495, 'SD', 7, 65, 44.4441, -98.7716, 'Moderate', 11843.0)
# (496, 'SD', 8, 47, 44.4158, -98.78, 'Good', 11846.0)
# (497, 'SD', 9, 35, 44.4438, -98.7799, 'Good', 9280.0)
# (498, 'SD', 10, 25, 44.4441, -98.7716, 'Good', 11722.0)
# (499, 'SD', 11, 25, 44.4445, -98.7626, 'Good', 15066.0)
# (500, 'SD', 12, 25, 44.4445, -98.7632, 'Good', 17869.0)
# (501, 'TN', 1, 31, 35.8171, -86.2041, 'Good', 103418.0)
# (502, 'TN', 2, 37, 35.8509, -86.3065, 'Good', 98294.0)
# (503, 'TN', 3, 37, 35.858, -86.026, 'Good', 63922.0)
# (504, 'TN', 4, 41, 35.8484, -86.0484, 'Good', 52112.0)
# (505, 'TN', 5, 42, 35.8533, -85.9856, 'Good', 48040.0)
# (506, 'TN', 6, 40, 35.8477, -86.0434, 'Good', 53962.0)
# (507, 'TN', 7, 50, 35.8518, -86.0069, 'Good', 57578.0)
# (508, 'TN', 8, 44, 35.8459, -86.0623, 'Good', 56002.0)
# (509, 'TN', 9, 38, 35.8503, -86.028, 'Good', 50120.0)
# (510, 'TN', 10, 34, 35.8461, -86.0261, 'Good', 44971.0)
# (511, 'TN', 11, 34, 35.82, -86.2541, 'Good', 67014.0)
# (512, 'TN', 12, 36, 35.8256, -86.1973, 'Good', 70171.0)
# (513, 'TX', 1, 36, 30.5209, -97.7965, 'Good', 723805.0)
# (514, 'TX', 2, 36, 30.5646, -97.8616, 'Good', 670429.0)
# (515, 'TX', 3, 44, 30.5753, -97.8815, 'Good', 565721.0)
# (516, 'TX', 4, 47, 30.5755, -97.8815, 'Good', 595286.0)
# (517, 'TX', 5, 42, 30.5577, -97.8988, 'Good', 602365.0)
# (518, 'TX', 6, 44, 30.6016, -97.865, 'Good', 698556.0)
# (519, 'TX', 7, 46, 30.5518, -97.9124, 'Good', 759297.0)
# (520, 'TX', 8, 43, 30.5508, -97.8598, 'Good', 765925.0)
# (521, 'TX', 9, 51, 30.5607, -97.8435, 'Moderate', 683408.0)
# (522, 'TX', 10, 40, 30.5569, -97.8812, 'Good', 639974.0)
# (523, 'TX', 11, 35, 30.5783, -97.8806, 'Good', 609673.0)
# (524, 'TX', 12, 38, 30.5716, -97.8581, 'Good', 637698.0)
# (525, 'UT', 1, 47, 39.8508, -111.7995, 'Good', 60102.0)
# (526, 'UT', 2, 40, 39.8507, -111.7995, 'Good', 50822.0)
# (527, 'UT', 3, 43, 39.8508, -111.7995, 'Good', 45206.0)
# (528, 'UT', 4, 48, 39.8507, -111.7995, 'Good', 36017.0)
# (529, 'UT', 5, 51, 39.8508, -111.7995, 'Moderate', 28581.0)
# (530, 'UT', 6, 60, 39.8507, -111.7995, 'Moderate', 30981.0)
# (531, 'UT', 7, 79, 39.8508, -111.7995, 'Moderate', 31450.0)
# (532, 'UT', 8, 80, 39.8508, -111.7995, 'Moderate', 27588.0)
# (533, 'UT', 9, 58, 39.8507, -111.7995, 'Moderate', 24998.0)
# (534, 'UT', 10, 38, 39.8508, -111.7995, 'Good', 24816.0)
# (535, 'UT', 11, 35, 39.8507, -111.7995, 'Good', 43292.0)
# (536, 'UT', 12, 42, 39.8508, -111.7995, 'Good', 59334.0)
# (537, 'VT', 1, 43, 44.0484, -73.105, 'Good', 3772.0)
# (538, 'VT', 2, 44, 44.0484, -73.105, 'Good', 3500.0)
# (539, 'VT', 3, 41, 44.0484, -73.105, 'Good', 3039.0)
# (540, 'VT', 4, 38, 44.0484, -73.105, 'Good', 2079.0)
# (541, 'VT', 5, 39, 44.0484, -73.105, 'Good', 1565.0)
# (542, 'VT', 6, 40, 44.0484, -73.105, 'Good', 1221.0)
# (543, 'VT', 7, 39, 44.0484, -73.105, 'Good', 1292.0)
# (544, 'VT', 8, 37, 44.0484, -73.105, 'Good', 1282.0)
# (545, 'VT', 9, 28, 44.0484, -73.105, 'Good', 1237.0)
# (546, 'VT', 10, 28, 44.0484, -73.105, 'Good', 1658.0)
# (547, 'VT', 11, 35, 44.0484, -73.105, 'Good', 2659.0)
# (548, 'VT', 12, 39, 44.0484, -73.105, 'Good', 3239.0)
# (549, 'VA', 1, 27, 37.5919, -78.6314, 'Good', 144810.0)
# (550, 'VA', 2, 29, 37.6182, -78.6208, 'Good', 117070.0)
# (551, 'VA', 3, 35, 37.6165, -78.6286, 'Good', 122269.0)
# (552, 'VA', 4, 39, 37.622, -78.6189, 'Good', 100607.0)
# (553, 'VA', 5, 38, 37.6172, -78.6238, 'Good', 81332.0)
# (554, 'VA', 6, 33, 37.6193, -78.6148, 'Good', 102158.0)
# (555, 'VA', 7, 44, 37.6246, -78.6225, 'Good', 107926.0)
# (556, 'VA', 8, 38, 37.639, -78.6047, 'Good', 107458.0)
# (557, 'VA', 9, 34, 37.6393, -78.6087, 'Good', 86748.0)
# (558, 'VA', 10, 30, 37.6702, -78.5897, 'Good', 84567.0)
# (559, 'VA', 11, 27, 37.6162, -78.6293, 'Good', 112305.0)
# (560, 'VA', 12, 31, 37.6254, -78.6137, 'Good', 127830.0)
# (561, 'WA', 1, 32, 47.1547, -121.0924, 'Good', 71512.0)
# (562, 'WA', 2, 24, 47.0913, -121.0166, 'Good', 70353.0)
# (563, 'WA', 3, 25, 47.087, -121.028, 'Good', 72675.0)
# (564, 'WA', 4, 25, 47.1685, -121.1054, 'Good', 52533.0)
# (565, 'WA', 5, 23, 47.1694, -121.0931, 'Good', 35531.0)
# (566, 'WA', 6, 26, 47.1705, -121.0587, 'Good', 37982.0)
# (567, 'WA', 7, 34, 47.1695, -121.031, 'Good', 44262.0)
# (568, 'WA', 8, 46, 47.169, -121.0993, 'Good', 45407.0)
# (569, 'WA', 9, 31, 47.1595, -121.0953, 'Good', 47422.0)
# (570, 'WA', 10, 24, 47.1378, -121.0513, 'Good', 55482.0)
# (571, 'WA', 11, 27, 47.1765, -121.0721, 'Good', 63384.0)
# (572, 'WA', 12, 24, 47.1604, -121.0984, 'Good', 83709.0)
# (573, 'WV', 1, 37, 39.3281, -81.1791, 'Good', 25746.0)
# (574, 'WV', 2, 44, 39.3267, -81.1907, 'Good', 23257.0)
# (575, 'WV', 3, 43, 39.3518, -81.1006, 'Good', 19566.0)
# (576, 'WV', 4, 44, 39.3597, -81.0498, 'Good', 17201.0)
# (577, 'WV', 5, 43, 39.3595, -81.041, 'Good', 14770.0)
# (578, 'WV', 6, 43, 39.3623, -81.0309, 'Good', 12588.0)
# (579, 'WV', 7, 51, 39.3603, -81.0596, 'Moderate', 12222.0)
# (580, 'WV', 8, 45, 39.3639, -81.0361, 'Good', 12730.0)
# (581, 'WV', 9, 38, 39.359, -81.0426, 'Good', 11133.0)
# (582, 'WV', 10, 31, 39.3592, -81.0488, 'Good', 15701.0)
# (583, 'WV', 11, 36, 39.3366, -81.1217, 'Good', 22589.0)
# (584, 'WV', 12, 40, 39.3325, -81.1465, 'Good', 20626.0)
# (585, 'WI', 1, 44, 43.6944, -89.4997, 'Good', 142221.0)
# (586, 'WI', 2, 45, 43.6944, -89.4997, 'Good', 140241.0)
# (587, 'WI', 3, 38, 43.623, -89.2914, 'Good', 104004.0)
# (588, 'WI', 4, 41, 43.6073, -89.0168, 'Good', 80205.0)
# (589, 'WI', 5, 42, 43.6036, -89.0168, 'Good', 62546.0)
# (590, 'WI', 6, 53, 43.6051, -89.0173, 'Moderate', 60342.0)
# (591, 'WI', 7, 48, 43.6036, -89.0168, 'Good', 61806.0)
# (592, 'WI', 8, 49, 43.5814, -89.0083, 'Good', 63261.0)
# (593, 'WI', 9, 38, 43.6023, -89.018, 'Good', 54359.0)
# (594, 'WI', 10, 32, 43.6371, -89.1481, 'Good', 70363.0)
# (595, 'WI', 11, 31, 43.7201, -89.4739, 'Good', 104011.0)
# (596, 'WI', 12, 38, 43.6821, -89.478, 'Good', 123142.0)
# (597, 'WY', 1, 35, 42.6364, -107.6174, 'Good', 18134.0)
# (598, 'WY', 2, 37, 42.6364, -107.6174, 'Good', 18044.0)
# (599, 'WY', 3, 40, 42.6467, -107.6155, 'Good', 15501.0)
# (600, 'WY', 4, 41, 42.6364, -107.6174, 'Good', 13440.0)
# (601, 'WY', 5, 41, 42.6364, -107.6174, 'Good', 12634.0)
# (602, 'WY', 6, 48, 42.6364, -107.6174, 'Good', 11616.0)
# (603, 'WY', 7, 71, 42.6364, -107.6174, 'Moderate', 10541.0)
# (604, 'WY', 8, 65, 42.6286, -107.6197, 'Moderate', 9908.0)
# (605, 'WY', 9, 52, 42.6364, -107.6174, 'Moderate', 10407.0)
# (606, 'WY', 10, 35, 42.6364, -107.6174, 'Good', 10564.0)
# (607, 'WY', 11, 34, 42.6364, -107.6174, 'Good', 15351.0)
# (608, 'WY', 12, 38, 42.6364, -107.6174, 'Good', 17408.0)

# %%
#converting the query result into a pandas DataFrame
query_list = []

for row in data_query:
    query_dics={
        'id':row.id,
        'state':row.state_id,
        'month':row.month,
        'AQI':row.AQI,
        'lat':row.lat,
        'lng':row.lng,
        'category':row.Category,
        'natural_gas_consumption':row.total
        }
    query_list.append(query_dics)

df = pd.DataFrame(query_list)
df.head()
# Out:
#    id state  month  AQI      lat      lng category  natural_gas_consumption
# 0   0    AL      1   37  33.3173 -86.8356     Good                 133551.0
# 1   1    AL      2   38  33.2297 -86.8105     Good                 114933.0
# 2   2    AL      3   43  33.1279 -86.8814     Good                 103717.0
# 3   3    AL      4   47  33.1279 -86.8814     Good                  96171.0
# 4   4    AL      5   44  33.1231 -86.8856     Good                 101999.0

# %% [markdown]
# ## Perform the seasonal Analysis
# - Focusing on Summer and Winter months

# %%
#Define a function for mapping months to seasons

def seasons(month):
    if month in [12,1,2]:
        return 'Winter'
    elif month in [6,7,8]:
        return 'Summer'
    else:
        return 'Other'
    
#applying the functino to create a new season column in our dataframe for each months numeric value
df['season'] = df['month'].apply(seasons)

df.head(10)
# Out:
#    id state  month  AQI      lat      lng category  natural_gas_consumption  \
# 0   0    AL      1   37  33.3173 -86.8356     Good                 133551.0
# 1   1    AL      2   38  33.2297 -86.8105     Good                 114933.0
# 2   2    AL      3   43  33.1279 -86.8814     Good                 103717.0
# 3   3    AL      4   47  33.1279 -86.8814     Good                  96171.0
# 4   4    AL      5   44  33.1231 -86.8856     Good                 101999.0
# 5   5    AL      6   38  33.1279 -86.8814     Good                 115579.0
# 6   6    AL      7   39  33.1369 -86.8778     Good                 119120.0
# 7   7    AL      8   42  33.1135 -86.8943     Good                 124022.0
# 8   8    AL      9   37  33.1279 -86.8814     Good                 109530.0
# 9   9    AL     10   37  33.1460 -86.8742     Good                 109041.0
#
#    season
# 0  Winter
# 1  Winter
# 2   Other
# 3   Other
# 4   Other
# 5  Summer
# 6  Summer
# 7  Summer
# 8   Other
# 9   Other

# %%
#Define a function for mapping months to seasons

def seasons(month):
    if month in [12,1,2]:
        return 'Winter'
    elif month in [6,7,8]:
        return 'Summer'
    else:
        return 'Other'
    
#applying the functino to create a new season column in our dataframe for each months numeric value
df['season'] = df['month'].apply(seasons)

df.head(10)
# Out:
#    id state  month  AQI      lat       lng  category  natural_gas_consumption  \
# 0   0    AK      1   58  61.4802 -143.6454  Moderate                  15243.0
# 1   1    AK      2   42  61.4802 -143.6454      Good                  15370.0
# 2   2    AK      3   29  61.4802 -143.6454      Good                  15715.0
# 3   3    AK      4   31  61.6964 -144.3220      Good                  11956.0
# 4   4    AK      5   24  61.4802 -143.6454      Good                   9288.0
# 5   5    AK      6   21  61.4802 -143.6454      Good                   7352.0
# 6   6    AK      7   29  61.4802 -143.6454      Good                   7429.0
# 7   7    AK      8   19  61.5467 -143.8536      Good                   8279.0
# 8   8    AK      9   18  61.4802 -143.6454      Good                   8563.0
# 9   9    AK     10   26  61.4802 -143.6454      Good                  12262.0
#
#    season
# 0  Winter
# 1  Winter
# 2   Other
# 3   Other
# 4   Other
# 5  Summer
# 6  Summer
# 7  Summer
# 8   Other
# 9   Other

# %%
df.count()
# Out:
# id                         609
# state                      609
# month                      609
# AQI                        609
# lat                        609
# lng                        609
# category                   609
# natural_gas_consumption    609
# season                     609
# dtype: int64

# %%
#filtering our dataframe based on season =winter and summer values
seasonal_df = df[df['season'].isin(['Winter','Summer'])]

seasonal_df.count()
# Out:
# id                         305
# state                      305
# month                      305
# AQI                        305
# lat                        305
# lng                        305
# category                   305
# natural_gas_consumption    305
# season                     305
# dtype: int64

# %%
#Group by state and season to aggregate the data
agg_df = seasonal_df.groupby(['state','season']).agg({
    'AQI':'mean',
    'natural_gas_consumption':'mean'
}).reset_index()

agg_df.head()
# Out:
#   state  season        AQI  natural_gas_consumption
# 0    AK  Summer  23.000000              7686.666667
# 1    AK  Winter  49.666667             20438.333333
# 2    AL  Summer  39.666667            119573.666667
# 3    AL  Winter  36.333333            122594.666667
# 4    AR  Summer  43.666667             54133.333333
